# %%
import pandas as pd

# %%
# Set the column width
pd.options.display.max_colwidth = 200

#  Read in the dataset.
df = pd.read_csv("../../04-Data-Analysis-Pandas/3/Activities/06-Evr_Crowdfunding_Cleaning/Unsolved/Resources/Crowdfunding_data.csv")
df
# Out:
#       id                          name  \
# 0      0    Baldwin, Riley and Jackson
# 1      1                      Odom Inc
# 2      2    Melton, Robinson and Fritz
# 3      3   Mcdonald, Gonzalez and Ross
# 4      4                 Larson-Little
# ..   ...                           ...
# 995  995              Manning-Hamilton
# 996  996                    Butler LLC
# 997  997                      Ball LLC
# 998  998   Taylor, Santiago and Flores
# 999  999  Hernandez, Norton and Kelley
#
#                                              blurb    goal  pledged  \
# 0             Pre-emptive tertiary standardization     100        0
# 1                 Managed bottom-line architecture    1400    14560
# 2     Function-based leadingedge pricing structure  108400   142523
# 3    Vision-oriented fresh-thinking conglomeration    4200     2477
# 4                        Proactive foreground core    7600     5265
# ..                                             ...     ...      ...
# ...

# %%
# split category to category and sub-category
df['subcategory'] = df['category'].str.split('/', expand=True)[1]
df['category'] = df['category'].str.split('/', expand=True)[0]
df
# Out:
#       id                          name  \
# 0      0    Baldwin, Riley and Jackson
# 1      1                      Odom Inc
# 2      2    Melton, Robinson and Fritz
# 3      3   Mcdonald, Gonzalez and Ross
# 4      4                 Larson-Little
# ..   ...                           ...
# 995  995              Manning-Hamilton
# 996  996                    Butler LLC
# 997  997                      Ball LLC
# 998  998   Taylor, Santiago and Flores
# 999  999  Hernandez, Norton and Kelley
#
#                                              blurb    goal  pledged  \
# 0             Pre-emptive tertiary standardization     100        0
# 1                 Managed bottom-line architecture    1400    14560
# 2     Function-based leadingedge pricing structure  108400   142523
# 3    Vision-oriented fresh-thinking conglomeration    4200     2477
# 4                        Proactive foreground core    7600     5265
# ..                                             ...     ...      ...
# ...

# %%
del df['id']

# %%
df['launched_at'] = pd.to_datetime(df['launched_at'], unit='s')
df['deadline'] = pd.to_datetime(df['deadline'], unit='s')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1000 non-null   object
#  1   blurb          1000 non-null   object
#  2   goal           1000 non-null   int64
#  3   pledged        1000 non-null   int64
#  4   outcome        1000 non-null   object
#  5   backers_count  1000 non-null   int64
#  6   country        1000 non-null   object
#  7   currency       1000 non-null   object
#  8   launched_at    1000 non-null   datetime64[ns]
#  9   deadline       1000 non-null   datetime64[ns]
#  10  staff_pick     1000 non-null   bool
#  11  spotlight      1000 non-null   bool
#  12  category       1000 non-null   object
#  13  subcategory    1000 non-null   object
# dtypes: bool(2), datetime64[ns](2), int64(3), object(7)
# memory usage: 95.8+ KB

# %%
from sqlalchemy import create_engine
from getpass import getpass

password = getpass(prompt='reika db password: ')

# Create engine
engine = create_engine(f'postgresql://reika:{password}@192.168.1.5:5432/crowdfunding')

# Load DataFrame to PostgreSQL table
df.to_sql('crowdfunding', engine, if_exists='replace', index=False)
# Out:
# reika db password:  ········
# 1000
